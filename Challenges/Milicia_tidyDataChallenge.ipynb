# %%
import json
import pandas as pd

# %% [markdown]
# ### Raw JSON Dict

# %%
with open('chessbuds_messages.json') as raw_data:
    chess_buds = json.load(raw_data)

# %%
# see what the top level keys are
chess_buds.keys()
# Out:
# dict_keys(['participants', 'messages', 'title', 'is_still_participant', 'thread_type', 'thread_path', 'magic_words', 'joinable_mode'])

# %% [markdown]
# ### Helper Functions (Style)

# %%
# method to style passed-in dataframe table-cells (td)
# chaining together style attributes makes it so the dataframe does not continuously switch object types
def styleTable(df, caption):
    styled_df = df.style.set_properties(**{'text-align':'left', 'overflow-wrap':'break-word'})\
        .set_table_styles([dict(selector = 'th', props=[('text-align','left')])])\
        .set_caption(caption)
    return styled_df

# %% [markdown]
# ### Participant DataFrame

# %%
# parse participant data
participants = chess_buds['participants']
title = chess_buds['title']

# create dataframe
df_part = pd.DataFrame(participants)

# pass dataframe to styling / caption method
df_part = styleTable(df_part, title + ': Participants')

#display dataframes
display(df_part)
# Out:
# <style type="text/css">
# #T_9bdab th {
#   text-align: left;
# }
# #T_9bdab_row0_col0, #T_9bdab_row1_col0, #T_9bdab_row2_col0, #T_9bdab_row3_col0, #T_9bdab_row4_col0, #T_9bdab_row5_col0, #T_9bdab_row6_col0 {
#   text-align: left;
#   overflow-wrap: break-word;
# }
# </style>
# <table id="T_9bdab">
#   <caption>Chess Buds: Participants</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bdab_level0_col0" class="col_heading level0 col0" >name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bdab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9bdab_row0_col0" class="data row0 col0" >Scott Pence</td>
#     </tr>
#     <tr>
#       <th id="T_9bdab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9bdab_row1_col0" class="data row1 col0" >Chad Larson</td>
#     </tr>
#     <tr>
#       <th id="T_9bdab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9bdab_row2_col0" class="data row2 col0" >Joanna Rusch</td>
#     </tr>
#     <tr>
#       <th id="T_9bdab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9bdab_row3_col0" class="data row3 col0" >Angela Babbitt Pence</td>
#     </tr>
#     <tr>
#       <th id="T_9bdab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9bdab_row4_col0" class="data row4 col0" >David Silva</td>
#     </tr>
#     <tr>
#       <th id="T_9bdab_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9bdab_row5_col0" class="data row5 col0" >Aaron Rusch</td>
#     </tr>
#     <tr>
#       <th id="T_9bdab_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9bdab_row6_col0" class="data row6 col0" >Timothy Vanderpool</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Messages DataFrame

# %%
# parse message data
messages = chess_buds['messages']

# create raw dataframe to preserve data
df_mess_raw = pd.DataFrame(messages)

# duplicate the raw data to a new editable dataframe
df_mess = df_mess_raw

# rename a few columns that are staying
df_mess = df_mess.rename(columns={"sender_name":"sender", "is_unsent":"is_draft", "is_taken_down":"is_removed"})

# %% [markdown]
# #### Timestamp Formatting

# %%
# create holder arrays
date_col = []
time_col = []

# loop through timestamp column data
for i in df_mess_raw['timestamp_ms']:
    # convert to timestamp
    ts = pd.to_datetime(i, unit='ms')
    
    # display as formatted string and add to holder arrays
    date_col.append(ts.strftime('%m/%d/%Y'))
    time_col.append(ts.strftime('%I:%M%p'))

# delete the unformatted timestamp column from the dupe datatable
del df_mess['timestamp_ms']

# insert the formatted time and date columns into the dupe datatable
df_mess.insert(0, 'date', date_col)
df_mess.insert(1, 'time', time_col)

# %% [markdown]
# #### Reaction Data Formatting

# %%
# create holder array
react_col = []

# loop through reaction column data
for j in df_mess_raw['reactions']:
    if type(j) == list:
        react_col.append(len(j))
    else:
        react_col.append(0)

# delete the unformatted reaction column from the dupe datatable
del df_mess['reactions']

# insert the formatted reaction count column into the dupe datatable
df_mess.insert(6, 'reaction_count', react_col)

# %% [markdown]
# #### Bumped Message Data Formatting

# %%
# create holder array
bump_col = []

# loop through bumped_message_metadata column data
for k in df_mess_raw['bumped_message_metadata']:
    bump_col.append(k['is_bumped'])

# delete the unformatted bumped_message_metadata column from the dupe datatable
del df_mess['bumped_message_metadata']

# insert the is_bumped column into the dupe datatable
df_mess.insert(8, 'is_bumped', bump_col)

# %% [markdown]
# #### Share Link Data Parsing

# %%
# create holder array
share_col = []

# loop through share column data
for l in df_mess_raw['share']:
    if type(l) == dict:
        share_col.append(True)
    else:
        share_col.append(False)

# delete the unformatted share column from the dupe datatable
del df_mess['share']

# insert the share_link column into the dupe datatable
df_mess.insert(9, 'has_link', share_col)

# %% [markdown]
# #### Photos Data Parsing

# %%
# create holder array
photo_col = []

# loop through photos column data
for m in df_mess_raw['photos']:
    if type(m) == list:
        photo_col.append(True)
    else:
        photo_col.append(False)

# delete the photo column from the dupe datatable
del df_mess['photos']

# insert the photo link column into the dupe datatable
df_mess.insert(10, 'has_photo', photo_col)

# %% [markdown]
# #### Gif Data Parsing

# %%
# create holder array
gif_col = []

# loop through gifs column data
for n in df_mess_raw['gifs']:
    if type(n) == list:
        gif_col.append(True)
    else:
        gif_col.append(False)

# delete the photo column from the dupe datatable
del df_mess['gifs']

# insert the photo link column into the dupe datatable
df_mess.insert(10, 'has_gifs', gif_col)

# %% [markdown]
# #### User Data Parsing

# %%
# create holder array
user_col = []

# loop through photos column data
for o in df_mess_raw['users']:
    if type(o) == list:
        user_col.append(o[0]['name'])
    else:
        user_col.append('--')

# reassign user column values
df_mess['users'] = user_col

# %% [markdown]
# ### DataFrame Styling & Display

# %%
# pass dataframe to styling / caption method
df_mess = styleTable(df_mess, title + ': Messages')

#display dataframes
display(df_mess)
# Out:
# <style type="text/css">
# #T_e31db th {
#   text-align: left;
# }
# #T_e31db_row0_col0, #T_e31db_row0_col1, #T_e31db_row0_col2, #T_e31db_row0_col3, #T_e31db_row0_col4, #T_e31db_row0_col5, #T_e31db_row0_col6, #T_e31db_row0_col7, #T_e31db_row0_col8, #T_e31db_row0_col9, #T_e31db_row0_col10, #T_e31db_row0_col11, #T_e31db_row0_col12, #T_e31db_row1_col0, #T_e31db_row1_col1, #T_e31db_row1_col2, #T_e31db_row1_col3, #T_e31db_row1_col4, #T_e31db_row1_col5, #T_e31db_row1_col6, #T_e31db_row1_col7, #T_e31db_row1_col8, #T_e31db_row1_col9, #T_e31db_row1_col10, #T_e31db_row1_col11, #T_e31db_row1_col12, #T_e31db_row2_col0, #T_e31db_row2_col1, #T_e31db_row2_col2, #T_e31db_row2_col3, #T_e31db_row2_col4, #T_e31db_row2_col5, #T_e31db_row2_col6, #T_e31db_row2_col7, #T_e31db_row2_col8, #T_e31db_row2_col9, #T_e31db_row2_col10, #T_e31db_row2_col11, #T_e31db_row2_col12, #T_e31db_row3_col0, #T_e31db_row3_col1, #T_e31db_row3_col2, #T_e31db_row3_col3, #T_e31db_row3_col4, #T_e31db_row3_col5, #T_e31db_row3_col6, #T_e31db_row3_col7, #T_e31db_row3_col8, #T_e31db_row3_col9, #T_e31db_row3_col10, #T_e31db_row3_col11, #T_e31db_row3_col12, #T_e31db_row4_col0, #T_e31db_row4_col1, #T_e31db_row4_col2, #T_e31db_row4_col3, #T_e31db_row4_col4, #T_e31db_row4_col5, #T_e31db_row4_col6, #T_e31db_row4_col7, #T_e31db_row4_col8, #T_e31db_row4_col9, #T_e31db_row4_col10, #T_e31db_row4_col11, #T_e31db_row4_col12, #T_e31db_row5_col0, #T_e31db_row5_col1, #T_e31db_row5_col2, #T_e31db_row5_col3, #T_e31db_row5_col4, #T_e31db_row5_col5, #T_e31db_row5_col6, #T_e31db_row5_col7, #T_e31db_row5_col8, #T_e31db_row5_col9, #T_e31db_row5_col10, #T_e31db_row5_col11, #T_e31db_row5_col12, #T_e31db_row6_col0, #T_e31db_row6_col1, #T_e31db_row6_col2, #T_e31db_row6_col3, #T_e31db_row6_col4, #T_e31db_row6_col5, #T_e31db_row6_col6, #T_e31db_row6_col7, #T_e31db_row6_col8, #T_e31db_row6_col9, #T_e31db_row6_col10, #T_e31db_row6_col11, #T_e31db_row6_col12, #T_e31db_row7_col0, #T_e31db_row7_col1, #T_e31db_row7_col2, #T_e31db_row7_col3, #T_e31db_row7_col4, #T_e31db_row7_col5, #T_e31db_row7_col6, #T_e31db_row7_col7, #T_e31db_row7_col8, #T_e31db_row7_col9, #T_e31db_row7_col10, #T_e31db_row7_col11, #T_e31db_row7_col12, #T_e31db_row8_col0, #T_e31db_row8_col1, #T_e31db_row8_col2, #T_e31db_row8_col3, #T_e31db_row8_col4, #T_e31db_row8_col5, #T_e31db_row8_col6, #T_e31db_row8_col7, #T_e31db_row8_col8, #T_e31db_row8_col9, #T_e31db_row8_col10, #T_e31db_row8_col11, #T_e31db_row8_col12, #T_e31db_row9_col0, #T_e31db_row9_col1, #T_e31db_row9_col2, #T_e31db_row9_col3, #T_e31db_row9_col4, #T_e31db_row9_col5, #T_e31db_row9_col6, #T_e31db_row9_col7, #T_e31db_row9_col8, #T_e31db_row9_col9, #T_e31db_row9_col10, #T_e31db_row9_col11, #T_e31db_row9_col12, #T_e31db_row10_col0, #T_e31db_row10_col1, #T_e31db_row10_col2, #T_e31db_row10_col3, #T_e31db_row10_col4, #T_e31db_row10_col5, #T_e31db_row10_col6, #T_e31db_row10_col7, #T_e31db_row10_col8, #T_e31db_row10_col9, #T_e31db_row10_col10, #T_e31db_row10_col11, #T_e31db_row10_col12, #T_e31db_row11_col0, #T_e31db_row11_col1, #T_e31db_row11_col2, #T_e31db_row11_col3, #T_e31db_row11_col4, #T_e31db_row11_col5, #T_e31db_row11_col6, #T_e31db_row11_col7, #T_e31db_row11_col8, #T_e31db_row11_col9, #T_e31db_row11_col10, #T_e31db_row11_col11, #T_e31db_row11_col12, #T_e31db_row12_col0, #T_e31db_row12_col1, #T_e31db_row12_col2, #T_e31db_row12_col3, #T_e31db_row12_col4, #T_e31db_row12_col5, #T_e31db_row12_col6, #T_e31db_row12_col7, #T_e31db_row12_col8, #T_e31db_row12_col9, #T_e31db_row12_col10, #T_e31db_row12_col11, #T_e31db_row12_col12, #T_e31db_row13_col0, #T_e31db_row13_col1, #T_e31db_row13_col2, #T_e31db_row13_col3, #T_e31db_row13_col4, #T_e31db_row13_col5, #T_e31db_row13_col6, #T_e31db_row13_col7, #T_e31db_row13_col8, #T_e31db_row13_col9, #T_e31db_row13_col10, #T_e31db_row13_col11, #T_e31db_row13_col12, #T_e31db_row14_col0, #T_e31db_row14_col1, #T_e31db_row14_col2, #T_e31db_row14_col3, #T_e31db_row14_col4, #T_e31db_row14_col5, #T_e31db_row14_col6, #T_e31db_row14_col7, #T_e31db_row14_col8, #T_e31db_row14_col9, #T_e31db_row14_col10, #T_e31db_row14_col11, #T_e31db_row ...

# %% [markdown]
# ---

# %% [markdown]
# # Observations and Assignment Details
#
# **Messages Table**
# - The object for this table (or observation) are messages with relation to date and time
# - Each row consists of message properties (e.g., sender, content, image files, reaction count)
# - Each column has been drilled down to a single, relevant variable
#
# This dataframe meets tiny data principles by only having a single observation type per table (messages over date and time) - It has single variables for each column (and they do not go deeper than a single value - And it has a single observation per row - meaning we are not comparing multiple things per row.
#
# **Alternatives**
# Some alternatives to this table might have been:
# - Sort this same list by sender
# - Shift to view all message data (e.g., count, total reactions, total shared images, etc.) per sender
# - Messages by date
#
# **Visualization Ideas**
# I think if this were to have been arranged by sender it might have been easier to drill to a macro level, but for this single one it could be interesting to plot message counts by date or perhaps by time.  You could also introduce senders specific data (e.g., what time of day / which days do certain people post more/less).
