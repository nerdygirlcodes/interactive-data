# %% [markdown]
# ## Task #1
#
# *In a new Jupyter Notebook, import pandas and matplotlib.pyplot*

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ---
# ## Task #2
#
# *Scroll through the matplotlib figure examples Links to an external site.and pick one style of figure you would like to learn how to create, then in a Markdown cell, explain what kind of data you would like to represent using that figure.*
#
# ---
# #### Matplotlib Categorical Heatmap
# We use heatmaps similar to this style quite often in my field.  The type of information we'd need would be two different verticies which cross reference each other at variable values / amounts.  (e.g., store location x service type = amount of appts for each)
#
# Demo code copied from:
#
# https://matplotlib.org/stable/gallery/images_contours_and_fields/image_annotated_heatmap.html#sphx-glr-gallery-images-contours-and-fields-image-annotated-heatmap-py
#
# Data altered to fit different example data, however, rendering code was copied 1:1.

# %%
# altered demo data, but code copied from above (as noted)
services = ["roll", "tires", "oil change", "break check",
              "alignment", "consultation", "other"]
locations = ["Vans Tires", "Conrads", "Goodyear Auto Service",
           "Just Tires", "TSN", "Partnerships (AAA)", "Dealer"]

appointments = np.array([[0.8, 2.4, 2.5, 3.9, 0.0, 4.0, 0.0],
                    [2.4, 0.0, 7.4, 1.0, 2.7, 0.0, 4.0],
                    [1.1, 2.4, 5.8, 4.3, 1.9, 4.4, 1.7],
                    [0.6, 0.0, 0.3, 0.0, 3.1, 0.0, 0.0],
                    [0.7, 1.7, 0.6, 2.6, 2.2, 6.2, 0.0],
                    [1.3, 1.2, 0.0, 0.0, 0.0, 3.2, 5.1],
                    [0.1, 2.0, 0.0, 1.4, 0.0, 1.9, 6.3]])


fig, ax = plt.subplots()
im = ax.imshow(appointments)

# Show all ticks and label them with the respective list entries
ax.set_xticks(np.arange(len(locations)), labels=locations)
ax.set_yticks(np.arange(len(services)), labels=services)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

# Loop over data dimensions and create text annotations.
for i in range(len(services)):
    for j in range(len(locations)):
        text = ax.text(j, i, appointments[i, j],
                       ha="center", va="center", color="w")

ax.set_title("Service Appointments (Appts/Day over 1 Month)")
fig.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Task #3
#
# *Download cces_example_data.csv using pandas.read_csv()*
# - *This data already follows tidy data principles*
# - *The variables `sex`, `pid3`, `nonwhite`, and `Evaluation` are all categorical variables, the rest can be treated as continuous*

# %%
# read the csv data and add to DataFrame
cces = pd.read_csv('cces_example_data.csv')

# set columns as categorical
cces = cces.astype({
    'sex':'category',
    'pid3':'category',
    'nonwhite':'category',
    'Evaluation':'category'
})

# display DataFrame
display(cces)
# Out:
#      pew_religimp  pew_churatd sex  educ nonwhite  age  faminc_new pid3  \
# 0               2            6   2     2        1   56           6    1
# 1               2            4   2     5        1   53          13    1
# 2               1            2   1     2        1   69          10    2
# 3               2            3   1     6        1   76          97    1
# 4               4            5   2     6        1   83           4    1
# ..            ...          ...  ..   ...      ...  ...         ...  ...
# 654             1            5   2     2        2   30           4    1
# 655             2            2   1     4        1   19          97    1
# 656             4            6   1     3        1   20           7    1
# 657             2            2   1     3        1   23           5    2
# 658             2            2   1     3        1   23           5    2
#
#      ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# ...

# %% [markdown]
# ---
# ## Task #4
#
# *Create and show in your notebook an empty figure that contains two axes*
# - *Set the title for the first axis as "Age Histogram"*
# - *Set the title for the second axis as "Political Identity"*

# %%
# create a new figure
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')  

# name axes
ax.set_ylabel('Age Histogram')
ax.set_xlabel('Political Identity')
# Out:
# Text(0.5, 0, 'Political Identity')

# %% [markdown]
# ---
# ## Task #5
#
# *In a new code cell, create and show a figure that includes one axis with a bar plot of the `Evaluation` variable*

# %%
# create a new figure 
fig2, ax2 = plt.subplots(figsize=(5, 2.7), layout='constrained')

# load in the evaluation variable
ax2.bar(cces.index, cces['Evaluation'])

# name the index axes
ax2.set_xlabel('CCES Data Index')
# Out:
# Text(0.5, 0, 'CCES Data Index')

# %%
# viewing data for 'Evaluation' variable in cces data
cces['Evaluation'].describe()
# Out:
# count     659
# unique      4
# top         0
# freq      365
# Name: Evaluation, dtype: int64

# %% [markdown]
# ---
# ## Task #6
#
# *In a new code cell, create and show a figure that includes one axis with a scatter plot of the `ConMediaUse` and `ImmiPhobia` variable.*

# %%
# create a new figure 
fig3, ax3 = plt.subplots(figsize=(5, 2.7), layout='constrained')

# create a scatter plot
ax3.scatter(cces['ImmiPhobia'], cces['ConMediaUse'])

# name the axes
ax3.set_xlabel('ImmiPhobia')
ax3.set_ylabel('ConMediaUse')
# Out:
# Text(0, 0.5, 'ConMediaUse')

# %%
# viewing data for 'ImmiPhobia' variable in cces data
cces['ImmiPhobia'].describe()
# Out:
# count    659.000000
# mean       2.327011
# std        1.040428
# min        1.000000
# 25%        1.500000
# 50%        2.500000
# 75%        3.000000
# max        5.000000
# Name: ImmiPhobia, dtype: float64

# %%
# viewing data for 'ConMediaUse' variable in cces data
cces['ConMediaUse'].describe()
# Out:
# count    659.000000
# mean       2.361659
# std        1.279250
# min        1.000000
# 25%        1.333333
# 50%        2.000000
# 75%        3.000000
# max        6.000000
# Name: ConMediaUse, dtype: float64
